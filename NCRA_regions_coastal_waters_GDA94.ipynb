# %% [markdown]
# # NCRA coastal waters
#
# The Australian Climate Service (ACS)
# defines a set of geographic regions defined for the National Climate Risk Assessment for coastal waters of Australia.
#
# This notebook gives a basic demonstration of the shapefiles found at:
# `/g/data/ia39/aus-ref-clim-data-nci/shapefiles/data/NCRA_regions_coastal_waters_GDA94/`
#
# The shapefiles were downloaded from: ????
# <!-- https://www.acs.gov.au/datasets/ -->

# %%
import geopandas as gp
from IPython.display import Image
import matplotlib.pyplot as plt

# %%
ncra_coastal_waters_file = '/g/data/ia39/aus-ref-clim-data-nci/shapefiles/data/NCRA_regions_coastal_waters_GDA94/NCRA_regions_coastal_waters_GDA94.shp'

# %%
ncra_coastal_waters = gp.read_file(ncra_coastal_waters_file)
ncra_coastal_waters
# Out:
#    fid  objectid                                               name  \
# 0  1.0         3  Coastal Waters (State Powers) Act 1980 - AMB20...
# 1  2.0         4  Coastal Waters (Northern Territory Powers) Act...
# 2  3.0         8  Coastal Waters (State Powers) Act 1980 - AMB20...
# 3  4.0         9  Coastal Waters (State Powers) Act 1980 - AMB20...
# 4  5.0         5  Coastal Waters (State Powers) Act 1980 - AMB20...
# 5  6.0         6  Coastal Waters (State Powers) Act 1980 - AMB20...
# 6  7.0         4  Coastal Waters (State Powers) Act 1980 - AMB20...
# 7  8.0         1  Coastal Waters (State Powers) Act 1980 - AMB20...
# 8  9.0         5  Coastal Waters (State Powers) Act 1980 - AMB20...
#
#                                              objnam  \
# 0     C2004A02276:Section3(1)(Area:New South Wales)
# 1  C2004A02277:Section3(1)(Area:Northern Territory)
# 2          C2004A02276:Section3(1)(Area:Queensland)
# 3          C2004A02276:Section3(1)(Area:Queensland)
# 4     C2004A02276:Section3(1)(Area:South Australia)
# 5                 C2004A02276:Section3(1)(Tasmania)
# 6            C2004A02276:Section3(1)(Area:Victoria)
# 7   C2004A02276:Section3(1)(Area:Western Australia)
# 8   C2004A02276:Section3(1)(Area:Western Australia)
#
#                                                  mrn          catlim nation  \
# 0  urn:mrn:mlb:AU:C2004A02276:Section3(1)(New Sou...  Coastal Waters     AU
# 1  urn:mrn:mlb:AU:C2004A02277:Section3(1)(Norther...  Coastal Waters     AU
# 2  urn:mrn:mlb:AU:C2004A02276:Section3(1)(Queensl...  Coastal Waters     AU
# 3  urn:mrn:mlb:AU:C2004A02276:Section3(1)(Queensl...  Coastal Waters     AU
# 4  urn:mrn:mlb:AU:C2004A02276:Section3(1)(South A...  Coastal Waters     AU
# 5   urn:mrn:mlb:AU:C2004A02276:Section3(1)(Tasmania)  Coastal Waters     AU
# 6   urn:mrn:mlb:AU:C2004A02276:Section3(1)(Victoria)  Coastal Waters     AU
# 7  urn:mrn:mlb:AU:C2004A02276:Section3(1)(Western...  Coastal Waters     AU
# 8  urn:mrn:mlb:AU:C2004A02276:Section3(1)(Western...  Coastal Waters     AU
#
#     phcs                                             legsou  \
# 0  GDA94            Coastal Waters (State Powers) Acts 1980
# 1  GDA94  Coastal Waters (Northern Territory Powers) Act...
# 2  GDA94            Coastal Waters (State Powers) Acts 1980
# 3  GDA94            Coastal Waters (State Powers) Acts 1980
# 4  GDA94            Coastal Waters (State Powers) Acts 1980
# 5  GDA94            Coastal Waters (State Powers) Acts 1980
# 6  GDA94            Coastal Waters (State Powers) Acts 1980
# 7  GDA94            Coastal Waters (State Powers) Acts 1980
# 8  GDA94            Coastal Waters (State Powers) Acts 1980
#
#                                            ip_owner  \
# 0  Commonwealth of Australia (Geoscience Australia)
# 1  Commonwealth of Australia (Geoscience Australia)
# 2  Commonwealth of Australia (Geoscience Australia)
# 3  Commonwealth of Australia (Geoscience Australia)
# 4  Commonwealth of Australia (Geoscience Australia)
# 5  Commonwealth of Australia (Geoscience Australia)
# 6  Commonwealth of Australia (Geoscience Australia)
# 7  Commonwealth of Australia (Geoscience Australia)
# 8  Commonwealth of Australia (Geoscience Australia)
#
#                                              licence  \
# 0  Creative Commons Attribution 4.0 International...
# 1  Creative Commons Attribution 4.0 International...
# 2  Creative Commons Attribution 4.0 International...
# 3  Creative Commons Attribution 4.0 International...
# 4  Creative Commons Attribution 4.0 International...
# 5  Creative Commons Attribution 4.0 International...
# 6  Creative Commons Attribution 4.0 International...
# 7  Creative Commons Attribution 4.0 International...
# 8  Creative Commons Attribution 4.0 International...
#
#                                           disclaimer  \
# 0  This data is a digital representation of lines...
# 1  This data is a digital representation of lines...
# 2  This data is a digital representation of lines...
# 3  This data is a digital representation of lines...
# 4  This data is a digital representation of lines...
# 5  This data is a digital representation of lines...
# 6  This data is a digital representation of lines...
# 7  This data is a digital representation of lines...
# 8  This data is a digital representation of lines...
#
#                                             frli_ref       date_      NCRA  \
# 0  https://www.legislation.gov.au/Series/C2004A02276  2019-08-30       NSW
# 1  https://www.legislation.gov.au/Series/C2004A02277  2019-08-30        NT
# 2  https://www.legislation.gov.au/Series/C2004A02276  2019-08-30  QLDNorth
# 3  https://www.legislation.gov.au/Series/C2004A02276  2019-08-30  QLDSouth
# 4  https://www.legislation.gov.au/Series/C2004A02276  2019-08-30        SA
# 5  https://www.legislation.gov.au/Series/C2004A02276  2019-08-30       TAS
# 6  https://www.legislation.gov.au/Series/C2004A02276  2019-08-30       VIC
# 7  https://www.legislation.gov.au/Series/C2004A02276  2019-08-30   WANorth
# 8  https://www.legislation.gov.au/Series/C2004A02276  2019-08-30   WASouth
#
#        label               regionname      area   perimeter  \
# 0        NSW          New South Wales  0.901184   48.708193
# 1         NT       Northern Territory  5.981539  116.845118
# 2  QLD North         Queensland North  9.471564  172.481007
# 3  QLD South         Queensland South  0.912874   28.104373
# 4         SA          South Australia  5.908875   74.065398
# 5        TAS                 Tasmania  2.606619  106.353471
# 6        VIC                 Victoria  1.034738   38.650827
# 7   WA North  Western Australia North  7.766966  199.491056
# 8   WA South  Western Australia South  2.592664   78.056813
#
#                                             geometry
# 0  MULTIPOLYGON (((150.59387 -35.18223, 150.59383...
# 1  MULTIPOLYGON (((135.74962 -14.78267, 135.75129...
# 2  MULTIPOLYGON (((143.65810 -11.83062, 143.65627...
# 3  POLYGON ((152.06163 -24.51975, 152.10666 -24.4...
# 4  MULTIPOLYGON (((137.23249 -36.44828, 137.23019...
# 5  MULTIPOLYGON (((146.96427 -43.91050, 146.96178...
# 6  MULTIPOLYGON (((147.06627 -39.15042, 147.06819...
# 7  MULTIPOLYGON (((113.89991 -27.22911, 113.89925...
# 8  MULTIPOLYGON (((116.21373 -35.06653, 116.21149...

# %%
ncra_regions.plot(
    figsize=[5, 5],
    column='label',
    legend=True,
    linewidth=0.1,
    edgecolor='black',
    legend_kwds={'loc': 'right', 'bbox_to_anchor': (1.5, 0.5)},
)
plt.title('NCRA coastal waters')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ncra_regions.plot(
#       2     figsize=[5, 5],
#       3     column='label',
#       4     legend=True,
#       5     linewidth=0.1,
#       6     edgecolor='black',
#       7     legend_kwds={'loc': 'right', 'bbox_to_anchor': (1.5, 0.5)},
#       8 )
#       9 plt.title('NCRA coastal waters')
#      10 plt.xlabel('Longitude')
#
# NameError: name 'ncra_regions' is not defined
